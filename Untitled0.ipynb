# %% [markdown]
# <a href="https://colab.research.google.com/github/audiblemaple/collab_test/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive" | grep DSC
# Out:
# DSC_3074.JPG
# DSC_3075.JPG
# DSC_3076.JPG
# DSC_3077.JPG
# DSC_3078.JPG
# DSC_3079.JPG
# DSC_3080.JPG
# DSC_3081.JPG
# DSC_9341.JPG
# DSC_9342.JPG

# %%
import numpy as np
from matplotlib import pyplot as plt
y = np.random.randn(100)
x = [x for x in range(len(y))]
plt.plot(x, y, '-')
plt.fill_between(x, y, 400, where = (y > 15), facecolor='g', alpha=0.6)
plt.title("Sample Plot")
plt.show()

# %%
# %%html
# <marquee style='width: 50%; color: Green;'>Welcome to cloud course!</marquee>
#
# slide 13
# %%html
# <svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
#    <rect x="10" y="00" width="300" height="100" rx="0" style="fill:red; stroke:black; fill-opacity:1.0" />
#    <rect x="10" y="100" width="300" height="100" rx="0" style="fill:blue; stroke:black; fill-opacity:1.0" />
#    <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0" />
# </svg>
# Out:
# <marquee style='width: 50%; color: Green;'>Welcome to cloud course!</marquee>
#
# slide 13
# %%html
# <svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
#    <rect x="10" y="00" width="300" height="100" rx="0" style="fill:red; stroke:black; fill-opacity:1.0" />
#    <rect x="10" y="100" width="300" height="100" rx="0" style="fill:blue; stroke:black; fill-opacity:1.0" />
#    <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0" />
# </svg>

# %%
# %history

# %%
sleeptime
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-8e96fa4c18c9> in <module>
# ----> 1 sleeptime
#
# NameError: name 'sleeptime' is not defined

# %%
# %%html
# <svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
#    <rect x="10" y="00" width="300" height="100" rx="0" style="fill:orange; stroke:black; fill-opacity:1.0" />
#    <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white; stroke:black; fill-opacity:1.0" />
#    <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0" />
# </svg>
# Out:
# <svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
#    <rect x="10" y="00" width="300" height="100" rx="0" style="fill:orange; stroke:black; fill-opacity:1.0" />
#    <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white; stroke:black; fill-opacity:1.0" />
#    <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0" />
# </svg>

# %%
# %%html
# <marquee style='width: 50%; color: Green;'>Welcome to cloud course!</marquee>
# Out:
# <marquee style='width: 50%; color: Green;'>Welcome to cloud course!</marquee>

# %%
color = 'red' #@param ["red", "green", "blue"] 
print(color)
# Out:
# blue

# %%
#@title Date fields 
date_input = '2019-06-13' #@param {type:"date"} 
print(date_input)

# %%
#@title Default title text
# %%html
<h1> </h1>
<style>
body {
  background-color: aquamarine;
}
</style>
color = 'green' #@param ["red", "green", "blue"] 
print(color) 
<svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
   <rect x="10" y="00" width="300" height="100" rx="0" style="fill:orange; stroke:black; fill-opacity:1.0" />
   <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white; stroke:black; fill-opacity:1.0" />
   <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0" />
</svg>
# Out:
# <h1> </h1>
# <style>
# body {
#   background-color: aquamarine;
# }
# </style>
# color = 'green' #@param ["red", "green", "blue"]
# print(color)
# <svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
#    <rect x="10" y="00" width="300" height="100" rx="0" style="fill:orange; stroke:black; fill-opacity:1.0" />
#    <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white; stroke:black; fill-opacity:1.0" />
#    <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0" />
# </svg>

# %%
with open('1.txt', 'r') as file:
  contents = file.read()
  print(contents)
  
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-41-e3d2150d9b83> in <module>
# ----> 1 with open('1.txt', 'r') as file:
#       2   contents = file.read()
#       3   print(contents)
#       4
#       5 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: '1.txt'

# %%
import ipywidgets as widgets
from IPython.display import display
button = widgets.Button(description="Click Me!")
output = widgets.Output()
def on_button_clicked(b):
  # Display the message within the output widget.
  with output:
    with open('/content/drive/My Drive/1.txt', 'r') as file:
      contents = file.read()
      print(contents)
button.on_click(on_button_clicked)
display(button, output)
# Out:
# Button(description='Click Me!', style=ButtonStyle())
# Output()

# %%
#@title cloud course
import time
sleeptime = 2
print(time.ctime())
time.sleep(sleeptime) 
print (time.ctime())
# Out:
# Mon Mar 20 15:09:07 2023
# Mon Mar 20 15:09:09 2023

# %%
name = 'cloud course' #@param {type:"string"} 
print(name)
# Out:
# Cloud course

# %%
ls /content/drive/MyDrive | grep stu
# Out:
# students.txt

# %%
with open('students.txt', 'r') as file:
  contents = file.read()
  print(contents)
  
file.close()
# Out:
# lior jigalo, 316109115, lior.jigalo@e.braude.ac.il, adventure time
# nitsan maman, 205798515, nitsan.maman@e.braude.ac.il, spongebob
# kfir hemo,  318262151,  kfir.hemo@e.braude.ac.il, dsadaaaaaaaaddddddddddddd
# gilad segal, ????????????, gilad.segal@e.braude.ac.il, something
# ron shahar, 206755712, ron.shahar@e.braude.ac.il, lost
# daniel vardimon, ???????????, daniel.vardimon@e.braude.ac.il, something

# %%
import ipywidgets as widgets
from IPython.display import display
button = widgets.Button(description="Click Me!")
output = widgets.Output()
def on_button_clicked(b):
  # Display the message within the output widget.
  with output:
    with open('/content/drive/My Drive/1.txt', 'r') as file:
      contents = file.read()
      print(contents)
button.on_click(on_button_clicked)
display(button, output)
# Out:
# Button(description='Click Me!', style=ButtonStyle())
# Output()

# %%
import ipywidgets as widgets
slider = widgets.IntSlider(value=50, max=100)
display(slider)
# Out:
# IntSlider(value=50)

# %%
with open('students.txt', 'w') as file:
  file.write('lior jigalo, 316109115, lior.jigalo@e.braude.ac.il, adventure time \n')
  file.write('nitsan maman, 205798515, nitsan.maman@e.braude.ac.il, spongebob \n')
  file.write('kfir hemo, 318262151, kfir.hemo@e.braude.ac.il, rick & morty \n')
  file.write('gilad segal, ????????????, gilad.segal@e.braude.ac.il, something \n')
  file.write('ron shahar, 206755712, ron.shahar@e.braude.ac.il, lost \n')
  file.write('daniel vardimon, ???????????, daniel.vardimon@e.braude.ac.il, something \n')
file.close()

# %%
import ipywidgets as widgets
from IPython.display import display

#@title Student select

with open('students.txt', 'r') as file:
  contents = file.read()  
file.close()

students = contents.split('\n')
choice = ""



w = widgets.Dropdown(options=["choose your pokemon","lior", "nitsan", "ron", "kfir", "gilad", "daniel"] )

t = widgets.Text()

b = widgets.Button(description="Update")

def on_button_clicked(b):
  # Display the message within the output widget.\
  for y in students:
    if y.find(w.value) != -1:
      splitted = y.split(",")
      break
  
  splitted[-1] = t.value
  
  str = splitted[0] + ", " + splitted[1] + ", " + splitted[2] + ", " + splitted[3]
  print(str)


  with open('students.txt', 'w') as file:
    i = 0
    for k in students:
      if  k.find(w.value) == -1:
        file.write(students[i] + '\n')
        i+= 1;
      else:
        file.write(str + '\n')
        i += 1
  file.close()





    # parsed = choice.split(",")
    # print(parsed[-1])
    # parsed[-1] = t.value
    # print(parsed)
    # for x in students:
    #   print(x[0])
    #   print(parsed)
    #   if parsed == x[0]:
    #      x[-1] = parsed[-1]    


    # with open('/content/drive/My Drive/1.txt', 'r') as file:
    #   contents = file.read()
    #   print(contents)


def on_change(change):
  
  global choice
  for x in students:
    if x.find(w.value) != -1:
      choice = x

  if w.value == "":
    return;

  if change['type'] == 'change' and change ['name'] == 'value':
    print ("\nChosen to: %s" % choice)


b.on_click(on_button_clicked)


w.observe(on_change)


display(w)
print("\n\n\nfavorite show:")
display(t)

print("\n")
display(b)
# Out:
# Dropdown(options=('choose your pokemon', 'lior', 'nitsan', 'ron', 'kfir', 'gilad', 'daniel'), value='choose yo…
# favorite show:
# Text(value='')
# Button(description='Update', style=ButtonStyle())
# Chosen to: kfir hemo, 318262151, kfir.hemo@e.braude.ac.il, rick & morty
# kfir hemo,  318262151,  kfir.hemo@e.braude.ac.il, dsadaaaaaaaaddddddddddddd
